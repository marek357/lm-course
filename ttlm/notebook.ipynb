# %%
#Change YOUR_GITHUB_USERNAME and YOUR_REPO after forking mine!
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive
# !git clone https://github.com/marek357/lm-course.git
# %cd /content/drive/MyDrive/lm-course/ttlm
# !git pull
# !pip install uv
# !uv sync
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive
# fatal: destination path 'lm-course' already exists and is not an empty directory.
# /content/drive/MyDrive/lm-course/ttlm
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 11 (delta 8), reused 11 (delta 8), pack-reused 0 (from 0)
# Unpacking objects: 100% (11/11), 7.90 KiB | 7.00 KiB/s, done.
# From https://github.com/marek357/lm-course
#    6c76f9f..63954b3  main       -> origin/main
# Updating 6c76f9f..63954b3
# error: Your local changes to the following files would be overwritten by merge:
# 	ttlm/uv.lock
# Please commit your changes or stash them before you merge.
# Aborting
# Requirement already satisfied: uv in /usr/local/lib/python3.12/dist-packages (0.9.7)

# %%
# !uv run python -m scripts.pretrain
# Out:
# Using CPython 3.14.0
# ^C
