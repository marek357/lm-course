# %%
# !rm -rf /content/drive/MyDrive/lm-course/
# Out:
# ^C

# %%
#Change YOUR_GITHUB_USERNAME and YOUR_REPO after forking mine!
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive
# !git clone https://github.com/marek357/lm-course.git testcourse
# %cd /content/drive/MyDrive/testcourse/ttlm
# !git pull
# !pip install uv
# !uv sync
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive
# fatal: destination path 'lm-course' already exists and is not an empty directory.
# /content/drive/MyDrive/lm-course/ttlm
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# ...
# error: No `pyproject.toml` found in current directory or any parent directory

# %%
# !uv run python -m scripts.pretrain
# Out:
# /root/.local/share/uv/python/cpython-3.14.0-linux-x86_64-gnu/bin/python3.14: Error while finding module specification for 'scripts.pretrain' (ModuleNotFoundError: No module named 'scripts')
